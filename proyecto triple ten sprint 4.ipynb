# %% [markdown]
# ¡Hola Nicolas! Como te va?
#
# Mi nombre es Facundo Lozano! Un gusto conocerte, seré tu revisor en este proyecto.
#
# A continuación un poco sobre la modalidad de revisión que usaremos:
#
# Cuando enccuentro un error por primera vez, simplemente lo señalaré, te dejaré encontrarlo y arreglarlo tú cuenta. Además, a lo largo del texto iré haciendo algunas observaciones sobre mejora en tu código y también haré comentarios sobre tus percepciones sobre el tema. Pero si aún no puedes realizar esta tarea, te daré una pista más precisa en la próxima iteración y también algunos ejemplos prácticos. Estaré abierto a comentarios y discusiones sobre el tema.
#
# Encontrará mis comentarios a continuación: **no los mueva, modifique ni elimine**.
#
# Puedes encontrar mis comentarios en cuadros verdes, amarillos o rojos como este:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor.</b> <a class="tocSkip"></a>
#
# Exito. Todo se ha hecho de forma exitosa.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor.</b> <a class="tocSkip"></a>
#
# Observación. Algunas recomendaciones.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor.</b> <a class="tocSkip"></a>
#
# Necesita arreglos. Este apartado necesita algunas correcciones. El trabajo no puede ser aceptado con comentarios rojos.
# </div>
#
# Puedes responder utilizando esto:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta de estudiante.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Review General. (Iteración 3) </b> <a class="tocSkip"></a>
#
# Felicitaciones Nicolas, has implementado los cambios que te he indicado, bien hecho! Hemos alcanzado los objetivos del proyecto por lo que está en condiciones de ser aprobado!
#
# Felicitaciones y éxitos en tu camino dentro del mundo de los datos!
#
# Saludos!

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Review General. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Nicolas, quería tomarme este tiempo al inicio de tu proyecto para comentarte mis apreciaciones generales de esta iteración de tu entrega.
#
# Siempre me gusta comenzar dando la bienvenida al mundo de los datos a los estudiantes, te deseo lo mejor y espero que consigas lograr tus objetivos. Personalmente me gusta brindar el siguiente consejo, "Está bien equivocarse, es normal y es lo mejor que te puede pasar. Aprendemos de los errores y eso te hará mejor programador ya que podrás descubrir cosas a medida que avances y son estas cosas las que te darán esa experiencia para ser un gran cientifico de datos."
#
# Ahora si yendo a esta notebook. Quería felicitarte porque has resuelto con creces todos los ejercicios planteados, más allá de un único ejercicio que no es determinante para rechazar la sección, lo has hecho espectacular. Felicitaciones. Por otro lado si que nos ha faltado dejar nuestras conclusiones en las últimas secciones, es de vital importancia poder expresar nuestros descubrimientos.
#
# Espero con ansias a nuestra próxima iteración con dichas conclusiones para aprobar el proyecto.
#
# Éxitos Nicolas! Un gusto

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.
# primero importamos pandas, despues leemos los archivos y agregamos el separador adecuado para poder leerlos correctamente
# despues llamamos a info en cada df para ver la informacion de estos.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt# importar librerías

# %%
instacart_orders_df=pd.read_csv('/datasets/instacart_orders.csv', sep=';')
products_df=pd.read_csv('/datasets/products.csv', sep=';')
aisles_df=pd.read_csv('/datasets/aisles.csv', sep=';')
departments_df=pd.read_csv('/datasets/departments.csv', sep=';')
order_products_df=pd.read_csv('/datasets/order_products.csv', sep=';')# leer conjuntos de datos en los DataFrames

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Excelente! Buena decisión la de importar las librerías y cargar los datos por separado, a la vez exclente presentación de plan. Sigamos!

# %%
instacart_orders_df.info()# mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
products_df.info()# mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
aisles_df.info()# mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
departments_df.info()# mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
order_products_df.info(show_counts=True)# mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
#
# Hemos mostrado info() para cada df y podemos notar que days_since_prior_order tiene valores ausentes en instacart_orders_df, product_name en products_df, y add_to_cart_order en order_products_df cuentan con valores ausentes

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Excelentes observaciones Nicolas! En avanzada te agradezco por el compromiso en tu comprensión de lo que vamos trabajando. Muy bien hecho!

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
# primero ver si instacart_orders_df tiene filas duplicadas y ver si tiene order_id duplicados mas adelante usamos drop_duplicates() para eliminar estos duplicados y verificamos que hayan sido eliminados de manera correcta.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Muy bien hecho! Los planes nos sirven para ordenarnos y pensar previamente todos los pasos que deberíamos hacer. Esto nos sirve para no olvidarnos de nada importante! Excelente!

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
instacart_orders_df.duplicated().sum()
# Out:
# 15

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
#
# Muy bien! Buena forma para verificar la cantidad de duplicados.

# %%
print(instacart_orders_df[instacart_orders_df['order_id'].duplicated()])

# Revisa si hay pedidos duplicados
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común? los duplicados tienen en comun las columnas order_dow y order_hour_of_day que dan el 3er dia y las 2 am, o sea miercoles a las 2am.

# %%
wed_2am_orders=instacart_orders_df.query("order_dow==3 and order_hour_of_day==2")# Basándote en tus hallazgos,
print(wed_2am_orders)# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Excelente! Buena forma para filtrar y corroborar lo que vimos anteriormente al ver los valores duplicados sobre columnas específicas. Sigamos!

# %% [markdown]
# ¿Qué sugiere este resultado? que 15 de los pedidos que fueron el miercoles a las 2 am son duplicados

# %%
instacart_orders_df=instacart_orders_df.drop_duplicates(subset='order_id')
# Elimina los pedidos duplicados

# %%
instacart_orders_df.duplicated().sum()

# Vuelve a verificar si hay filas duplicadas
# Out:
# 0

# %%
instacart_orders_df['order_id'].duplicated().sum()# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Nuevamente bien hecho al eliminar los duplicados, para mejorarlo se podría implementar el método **reset_index**, una buena práctica a implementar siempre luego de eliminar duplicados.. Sigamos!

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos: encontre duplicados y despues los duplicados fueron eliminados exitosamente.

# %% [markdown]
# ### `products` data frame

# %%
products_df.duplicated().sum()# Verifica si hay filas totalmente duplicadas
# Out:
# 0

# %%
products_df['department_id'].duplicated().sum()

# Revisa únicamente si hay ID de departamentos duplicados
# Out:
# 49673

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Excelente corroboración de duplicados y de valores únicos por **department_id**. Lo has hecho muy bien!

# %%
products_df['product_name']= products_df['product_name'].str.upper()
products_df['product_name'].duplicated().sum()#Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
# Out:
# 1361

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Nuevamente excelentes procedimientos Nicolas, normalizamos llevando a mayusculas y corroboramos duplicados. Bien hecho!

# %%
null_prod_name=~products_df['product_name'].isna()
print(null_prod_name.duplicated().sum())
# Revisa si hay nombres duplicados de productos no faltantes
# Out:
# 49692

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Excelente corroboración de duplicados sobre productos no faltantes. Sigamos!

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# tome products_name_upper y le aplique isna() para obtener los valores ausentes
# para obtener los valores no faltantes utilize '~' y lo puse en una variable nueva la cual imprime llamando a duplicated().sum() y dio un total de 49692.

# %% [markdown]
# ### `departments` data frame

# %%
departments_df.duplicated().sum()# Revisa si hay filas totalmente duplicadas
# Out:
# 0

# %%
departments_df['department_id'].duplicated().sum()# Revisa únicamente si hay IDs duplicadas de productos: ya que solo hay columna department y department_id, utiize department_id.
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Muy bien, excelente! Nuevamente buena forma para verificar la cantidad de duplicados. En este caso no tenemos por lo que podemos seguir adelante.

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# No se encontraron duplicados.

# %% [markdown]
# ### `aisles` data frame

# %%
aisles_df.duplicated().sum()# Revisa si hay filas totalmente duplicadas
# Out:
# 0

# %%
aisles_df['aisle_id'].duplicated().sum()# Revisa únicamente si hay IDs duplicadas de productos:ya que solo hay columnas 'aisle' y 'aisle_id' utilize 'aisle_id'
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Misma situación, bien hecho!

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# No se encontraron duplicados

# %% [markdown]
# ### `order_products` data frame

# %%
order_products_df.duplicated().sum()# Revisa si hay filas totalmente duplicadas
# Out:
# 0

# %%
order_products_df['order_id'].duplicated().sum()
# Vuelve a verificar si hay cualquier otro duplicado engañoso
# Out:
# 4094961

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Nuevamente muy bien hecho Nicolas, excelente calculo de duplicados por la columna correspondiente.

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos: algunas columnas me marcaron duplicados muy altos e intente deshacerme de ellos pero no funcionaba y aun asi se me hacia muy raro por lo que en realidad no supe que hacer.

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
prod_name_absent_values=products_df[products_df['product_name'].isna()]
print(prod_name_absent_values)# Encuentra los valores ausentes en la columna 'product_name'
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Muy bien identificados los valores nulos sobre **products_name**. Felicitaciones, sigue así que lo estás haciendo perfecto!

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. hay 1258 valores asuentes en la columna 'product_name', llame a value_counts() en products_df['product_name'] y lo puse en una varable llamada prod_name_absent_values para poder utilizarla mas adelante.

# %%
aisle_100= products_df.query("aisle_id==100")
prod_name_absent_values.isin(aisle_100).sum()#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
# si, todos los nombres de productos ausentes estan relacionados con el pasillo de ID 100
# Out:
# product_id       1258
# product_name        0
# aisle_id         1258
# department_id    1258
# dtype: int64

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. podemos observar que en el aisle 100 hay 1258 productos y al llamar isin() en prod_name_absent_values para ver si estan en aisle 100 recibimos que en 'product_name' no hay un solo valor mientras que en el resto de las columnas obtenemos los 1258 productos, por lo tanto el total de los 'product_name' ausentes estan relacionados con el aisle 100.

# %%
dept_21= products_df.query("department_id==21")
prod_name_absent_values.isin(dept_21).sum()
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
# todos los nombres de productos ausentes estan relacionados con el departamento con ID 21.
# Out:
# product_id       1258
# product_name        0
# aisle_id         1258
# department_id    1258
# dtype: int64

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.

# %%
print(aisle_100)
print(dept_21)# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
#en esta celda mostre aisle_100 y dept_21 para poder ver los datos
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Bien hecho Nicolas! Corroboraste un dato importante, ahora podemos asegurar que el valor 100 para "aisle_id" es un valor a tener en cuenta e investigar junto a deparment_id y su valor 21.

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. como se puede observar cuando imprimimos 'aisle_100' que muestra el aisle_id = 100, todos los valores de la columna 'product_name' muestran NaN.
# De igual manera cuando imprimimos 'dept_21' que muestra el dept_id = 21, todos los valores de la columna 'product_name' muestran NaN.

# %%
products_df['product_name'].fillna('Unknown', inplace=True)
new_product_name=products_df.query("product_name=='Unknown'")
new_aisle_100=products_df.query("aisle_id==100")
print(new_aisle_100)# Completa los nombres de productos ausentes con 'Unknown'
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38      Unknown       100             21
# 71             72      Unknown       100             21
# 109           110      Unknown       100             21
# 296           297      Unknown       100             21
# 416           417      Unknown       100             21
# ...           ...          ...       ...            ...
# 49552       49553      Unknown       100             21
# 49574       49575      Unknown       100             21
# 49640       49641      Unknown       100             21
# 49663       49664      Unknown       100             21
# 49668       49669      Unknown       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Bien resuelto! En este caso es importante no eliminar estas filas ya que a pesar de tener un valor faltante, aún tenemos información de utilidad en otras columnas, por esta razón es acertado reemplazar dicho valor con "Unknown". Felicitaciones!

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# Ahora Nan en la columna 'product_name' ha sido remplazado por 'unknown'.

# %% [markdown]
# ### `orders` data frame

# %%
print(instacart_orders_df.isna().sum())
dspo_absents=instacart_orders_df[instacart_orders_df['days_since_prior_order'].isna()]
print(dspo_absents)
# Encuentra los valores ausentes
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 28        133707   182261             1          3                 10
# 96        787445    25685             1          6                 18
# 100       294410   111449             1          0                 19
# 103      2869915   123958             1          4                 16
# 104      2521921    42286             1          3                 18
# ...          ...      ...           ...        ...                ...
# 478895   2589657   205028             1          0                 16
# 478896   2222353   141211             1          2                 13
# 478922   2272807   204154             1          1                 15
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Excelente resolución Nicolas! Bien hecho!

# %% [markdown]
# ¿Hay algún valor ausente que no sea el primer pedido del cliente? No, todos los valores NaN son por que solo hay un pedido para ese usuario por lo tanto la columna days_since_prior_order
# NaN

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Excelente justificación Nicolas, sin embargo sería de gran ayuda poder observarlo mediante código, a lo que habías filtrado anteriormente deberíamos agregarle la condición de filtrado por **order_numer != 1**

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.:
# Todos los valores ausentes en la columna 'days_since_prior_order' se encuentran vacios dado que el usuario no ha realizado un pedido anteriormente, para confirmar esto btuve todos los valores de 'order_number'== 1 y el numero de filas fue el mismo numero que el de las que tenian valores ausentes, pero para confirmarloconverti los valores ausentes a 'None' y con .query() filtre las filas con las columnas 'order_number'==1 y 'days_since_prior_order=='None'.

# %% [markdown]
# ### `order_products` data frame

# %%
print(order_products_df.isna().sum())

atco_absents=order_products_df[order_products_df['add_to_cart_order'].isna()]
print(atco_absents)# Encuentra los valores ausentes
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                NaN          0
# 9926      1968313       43867                NaN          0
# 14394     2926893       11688                NaN          0
# 16418     1717990        4142                NaN          0
# 30114     1959075       42828                NaN          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [836 rows x 4 columns]

# %%
print("add_to_cart_order max value:", order_products_df['add_to_cart_order'].max() )# ¿Cuáles son los valores mínimos y máximos en esta columna?64 y 1
print("add_to_cart_order min value:",order_products_df['add_to_cart_order'].min() )
# Out:
# add_to_cart_order max value: 64.0
# add_to_cart_order min value: 1.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Perfecto! Buena aplicación de los métodos y buena presentación de resultados. Sigamos!

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# El valor mas alto encontrado en la columna add_to_cart_order fue de 64.0 y el mas bajo fue de 1.0.

# %%
missing_add_to_cart= order_products_df['add_to_cart_order'].isna()
missing_atco_rows = order_products_df[missing_add_to_cart]
missing_order_ids=missing_atco_rows['order_id'].unique()
print(missing_order_ids)# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
# Out:
# [2449164 1968313 2926893 1717990 1959075  844733   61355  936852  264710
#  1564093  129627  293169 2849370 1386261 3308010  903110 2136777 3347453
#  1888628  165801 2094761 1038146 2997021  813364 2256933  171934 2409109
#  1730767 1169835  733526  404157 3125735  747668 1800005 1961723  871281
#   388234 1648217 1477139  102236 1021563 1832957 2721963  678116 1220886
#  1673227 2999801 1633337 2470674 2625444 1677118 2479011 3383594 1183255
#  1713430 2652650 1598369 1916118  854647 1302315  888470  180546 2621907
#  1308785 2729254    9310 2170451 2979697 1625713 1529171]

# %%
missing_order_ids_in_df=order_products_df[order_products_df['order_id'].isin(missing_order_ids)]
missing_order_ids_count=missing_order_ids_in_df['order_id'].value_counts()
print((missing_order_ids_count).min())
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?  si, todos tienen mas de 64 productos siendo el mas bajo de 65.
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
# Out:
# 65

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Bien resuelto! Utilizaste un enfoque interesante para descartar la afirmación de la pregunta. Bien pensado!

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.:
# Se encontro que los pedidos con valores ausentes en la columna 'add_to_cart_order' tienen al menos 65 productos por lo que para responder la pregunta ¿Todos los pedidos con valores ausentes tienen más de 64 productos? si, todos tienen al menos 65 productos.

# %%
order_products_df['add_to_cart_order'].fillna(999, inplace=True)
order_products_df['add_to_cart_order']= order_products_df['add_to_cart_order'].astype(int)
order_products_df.info()
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 138.7 MB

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Buena resolución para completar estos valores! Sencilla y directa, felicitaciones!.

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.:
# los valores ausentes de la columna 'add_to_cart_order' han sido reemplazados por 999 y el tipo de datos de esa columna ha sido cambiada de float64 a int64 y lo confirme llamando a info() en el order_products_df.

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos
# Ahora los valores de los dataframes deberian de estar listos sin duplicados ni valores ausentes donde no los debe de haber para poder trabajar con ellos y conseguir resultados correctos.

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
print("order hour of day min value:", instacart_orders_df['order_hour_of_day'].min())
print("order hour of day max value:", instacart_orders_df['order_hour_of_day'].max())
print("order day of week min value:", instacart_orders_df['order_dow'].min())
print("order day of week min value:", instacart_orders_df['order_dow'].max())
# Out:
# order hour of day min value: 0
# order hour of day max value: 23
# order day of week min value: 0
# order day of week min value: 6

# %%
orders_by_hour = instacart_orders_df.groupby('order_hour_of_day')['user_id'].nunique() #orders_by_hour para saber cuantos pedidos se hacen en cada hora
plt.figure(figsize=(10, 6))  
plt.plot(orders_by_hour.index, orders_by_hour.values, marker='*') 
plt.xlabel('Hora del Día') 
plt.ylabel('Número de usuarios que hacen pedidos')
plt.title('Número de Usuarios que hacen ordenes por Hora del Día')  
plt.grid(True) 

plt.show()

# %% [markdown]
#  <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Una forma creativa de corroborar lo pedido, eso demuestra comprensión e inteligencia. Muy bien Nicolas! Sigamos que falta poco!

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
orders_by_hour = instacart_orders_df.groupby('order_hour_of_day')['user_id'].nunique()
print(orders_by_hour)
# Out:
# order_hour_of_day
# 0      2991
# 1      1671
# 2       958
# 3       744
# 4       735
# 5      1281
# 6      3757
# 7     10993
# 8     20268
# 9     28112
# 10    32195
# 11    32660
# 12    31754
# 13    32433
# 14    32797
# 15    32894
# 16    31579
# 17    26825
# 18    21795
# 19    17026
# 20    12891
# 21     9806
# 22     7670
# 23     5167
# Name: user_id, dtype: int64

# %% [markdown]
# Escribe aquí tus conclusiones
# la hora con mas personas que piden es a las 15 horas mientras que la hora con menos personas que piden es a las 4 am.

# %%
orders_by_dow = instacart_orders_df.groupby('order_dow')['user_id'].nunique()
plt.figure(figsize=(10, 6))  
plt.plot(orders_by_dow.index, orders_by_dow.values, marker='*') 
plt.xlabel('dia de la semana') 
plt.ylabel('Número de usuarios que hacen pedidos') 
plt.title('Numero de usuarios que hacen ordenes por dia')
plt.grid(True)

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Cuidado aquí, has calculado correctamente lo que necesitabamos cuando aplicaste la agrupación sobre **order_hour_of_day**, sin embargo aquí estamos mostrando otra gráfica que no responde al ejercicio. Deberíamos aplicarla sobre la columna que te mencioné, incluso la mostraste en el ejercicio anterior. Por estas razones lo marco como una simple recomendación.

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
orders_by_dow = instacart_orders_df.groupby('order_dow')['order_id'].nunique()
print(orders_by_dow)
plt.figure(figsize=(10,6))
orders_by_dow.plot(kind='bar')
plt.title('Cantidad de órdenes únicas por día de la semana')
plt.xlabel('Día de la semana')
plt.ylabel('Cantidad de órdenes únicas')
# Out:
# order_dow
# 0    84090
# 1    82185
# 2    65833
# 3    60897
# 4    59810
# 5    63488
# 6    62649
# Name: order_id, dtype: int64
# Text(0, 0.5, 'Cantidad de órdenes únicas')

# %% [markdown]
#  <div class="alert alert-block alert-warning">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Cuidado aquí, pensemos en que nos solicitan que de de la semana se compran víveres, es decir que nuestra agrupación es correcta por **order_dow** sin embargo no deberíamos pensar en los usuarios para llebar a cabo esta agrupación sino en las compras, es decir **order_id**. Trata de corregir esto y recuerda graficar los resultados en un gráfico de barras.

# %% [markdown]
#  <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 2)</b> <a class="tocSkip"></a>
#
# Excelente corrección Nicolas! Muy bien hecho!

# %% [markdown]
# Escribe aquí tus conclusiones:
# El dia Domingo es el dia en el que mas compras se hacen mientras que el dia Jueves es el dia que menos pedidos se hacen.

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos. :
# la gran mayoria de los usuarios se toma 30 dias para volver a realizar un pedido siendo estos 44,444 mientras que 2620 usuarios se toman 26 dias para volver a realizar un pedido siendo este el menor.

# %%
days_since_prior_order_users = instacart_orders_df.groupby('days_since_prior_order')['user_id'].nunique()
print(days_since_prior_order_users)
# Out:
# days_since_prior_order
# 0.0      7532
# 1.0     13286
# 2.0     17552
# 3.0     20426
# 4.0     22347
# 5.0     23330
# 6.0     26812
# 7.0     32021
# 8.0     21772
# 9.0     15354
# 10.0    12412
# 11.0    10847
# 12.0    10177
# 13.0    11172
# 14.0    13080
# 15.0     9044
# 16.0     6411
# 17.0     5368
# 18.0     4896
# 19.0     4835
# 20.0     5187
# 21.0     6276
# 22.0     4439
# 23.0     3285
# 24.0     2974
# 25.0     2690
# 26.0     2620
# 27.0     2961
# 28.0     3684
# 29.0     2647
# 30.0    44444
# Name: user_id, dtype: int64

# %%
days_since_prior_order_users = instacart_orders_df.groupby('days_since_prior_order')['user_id'].nunique()
plt.figure(figsize=(8, 6))
plt.bar(days_since_prior_order_users.index, days_since_prior_order_users.values, color='orange')  
plt.ylabel('Cantidad de usuarios')  
plt.xlabel('Dias desde el ultimo pedido')  
plt.title('Dias que los usuarios tardan para hacer otro pedido') 
plt.grid(True)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Impresionante Nicolas, nuevamente lo has resuelta tal como correspondía!

# %% [markdown]
# Escribe aquí tus conclusiones: parece ser que algunos usuarios volvieron a realizar un pedido dentro de los primeros 7 dias y de ahi en adelante parece ser va disminuyendo la cantidad de usuarios que vuelven a comprar hasta el dia 30 que es cuando llega al punto mas alto de clientes.

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
orders_wednesday = instacart_orders_df[instacart_orders_df['order_dow'] == 3]
orders_saturday = instacart_orders_df[instacart_orders_df['order_dow'] == 6]
hourly_distribution_wednesday = orders_wednesday['order_hour_of_day'].value_counts().sort_index()
hourly_distribution_saturday = orders_saturday['order_hour_of_day'].value_counts().sort_index()
plt.bar(hourly_distribution_wednesday.index, hourly_distribution_wednesday.values, 
        color='blue', alpha=0.7, label='Miércoles')
plt.bar(hourly_distribution_saturday.index, hourly_distribution_saturday.values, 
        color='green', alpha=0.7, label='Sábado')
plt.xlabel('Hora del Día')
plt.ylabel('Número de Pedidos')
plt.title('Distribución de Horas de Pedido (Miércoles vs. Sábado)')
plt.xticks(range(24))  
plt.legend()  
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Un procedimiento perfecto, en primera instancia hemos calculado las frecuencias y luego implementamos el gráfico objetivo al comparar a ámbas en el mismo gráfico. Excelente! Si quisieramos verlo de una mejor forma podríamos mostrar las 2 barras separadas por valor.

# %% [markdown]
# Escribe aquí tus conclusiones:
#     Se puede observar que a partir de las 10 am hasta las 5 pm son las horas en las que mas se ordena para ambos dias.
#     Tambien podemos observar que el dia sabado a las 12pm hasta las 2pm el numero de ordenes es mas alto que en los dias miercoles para las mismas horas probablemente por que las personas tienen mas  tiempo libre los sabados.

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
ordenes_por_usuario = instacart_orders_df['user_id'].value_counts()
distribucion_de_ordenes= ordenes_por_usuario.value_counts()
distribucion_de_ordenes.plot(figsize=[12,6], kind='bar', xlabel='Numero de ordenes por clientes', ylabel='Numero de clientes', title='Distribución del Número de Órdenes por Cliente')
plt.show()

# %%
print(distribucion_de_ordenes.sort_values())
# Out:
# 28        1
# 25        1
# 26        1
# 24        3
# 23       19
# 21       22
# 22       23
# 20       52
# 19       85
# 18      121
# 17      184
# 16      263
# 15      437
# 14      512
# 13      703
# 12      947
# 11     1308
# 10     1645
# 9      2152
# 8      3019
# 7      4240
# 6      6012
# 5      8777
# 4     13498
# 3     21547
# 2     36508
# 1     55357
# Name: user_id, dtype: int64

# %%
print('Se puede ver en el grafico que la gran mayoria de los usuarios realizaron un solo pedido siendo estos 55357 y se puede notar que el numero de clientes que realizaron mas pedidos solo va disminuyendo habiendo solo un cliente que realizo 28 pedidos.')
# Out:
# Se puede ver en el grafico que la gran mayoria de los usuarios realizaron un solo pedido siendo estos 55357 y se puede notar que el numero de clientes que realizaron mas pedidos solo va disminuyendo habiendo solo un cliente que realizo 28 pedidos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Excelente Nicolas, una calculo de frecuencia perfecta!

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
product_order_counts = order_products_df['product_id'].value_counts()
top_20_product_ids = product_order_counts.head(20).index
top_20_products = products_df[products_df['product_id'].isin(top_20_product_ids)]
print(top_20_products[['product_id', 'product_name']])
# Out:
#        product_id              product_name
# 5875         5876             ORGANIC LEMON
# 8276         8277  APPLE HONEYCRISP ORGANIC
# 13175       13176    BAG OF ORGANIC BANANAS
# 16796       16797              STRAWBERRIES
# 21136       21137      ORGANIC STRAWBERRIES
# 21902       21903      ORGANIC BABY SPINACH
# 22934       22935      ORGANIC YELLOW ONION
# 24851       24852                    BANANA
# 24963       24964            ORGANIC GARLIC
# 26208       26209                     LIMES
# 27844       27845        ORGANIC WHOLE MILK
# 27965       27966       ORGANIC RASPBERRIES
# 28203       28204        ORGANIC FUJI APPLE
# 39274       39275       ORGANIC BLUEBERRIES
# 40705       40706    ORGANIC GRAPE TOMATOES
# 45006       45007          ORGANIC ZUCCHINI
# 47208       47209      ORGANIC HASS AVOCADO
# 47625       47626               LARGE LEMON
# 47765       47766           ORGANIC AVOCADO
# 49682       49683            CUCUMBER KIRBY

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Nuevamente hemos llegado al calculo esperado, muy bien hecho! Sigamos!

# %% [markdown]
# Escribe aquí tus conclusiones: en la tabla se pueden observar los 20 productos mas populares junto con sus ids y podemos observar que los 20 productos mas populares son productos organicos y considerados saludables.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
items_per_order = order_products_df.groupby('order_id').size()
average_items_per_order = items_per_order.mean()
print("Número promedio de artículos por pedido:", average_items_per_order)
plt.figure(figsize=(10, 6))
plt.hist(items_per_order, bins=30, edgecolor='black')
plt.title('Distribución del número de artículos por pedido')
plt.xlabel('Número de artículos por pedido')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# Número promedio de artículos por pedido: 10.098983215049127

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Perfecto Nicolas, aquì podríamos visualizar con mayor precisión esta distribución con un gráfico de barras pero de todas formas esta muy bien resuelto. Felicitaciones!

# %% [markdown]
# Escribe aquí tus conclusiones:
# El numero promedio de articulos por pedido es de 10.098 aunque lo mas frecuente es que el usuario pida entre 2 y 5 articulos por pedido y habiendo unos pocos usuarios que piden hasta 40-45 articulos por pedido.

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
reorder_counts = order_products_df.groupby('product_id')['reordered'].sum()
top_reordered_product_ids = reorder_counts.sort_values(ascending=False).head(20).index
top_reordered_products = products_df[products_df['product_id'].isin(top_reordered_product_ids)]
print("Los 20 principales productos reordenados:")
print(top_reordered_products[['product_id', 'product_name']])
# Out:
# Los 20 principales productos reordenados:
#        product_id              product_name
# 5875         5876             ORGANIC LEMON
# 8276         8277  APPLE HONEYCRISP ORGANIC
# 13175       13176    BAG OF ORGANIC BANANAS
# 16796       16797              STRAWBERRIES
# 21136       21137      ORGANIC STRAWBERRIES
# 21902       21903      ORGANIC BABY SPINACH
# 22934       22935      ORGANIC YELLOW ONION
# 24851       24852                    BANANA
# 24963       24964            ORGANIC GARLIC
# 26208       26209                     LIMES
# 27844       27845        ORGANIC WHOLE MILK
# 27965       27966       ORGANIC RASPBERRIES
# 28203       28204        ORGANIC FUJI APPLE
# 39274       39275       ORGANIC BLUEBERRIES
# 45006       45007          ORGANIC ZUCCHINI
# 47208       47209      ORGANIC HASS AVOCADO
# 47625       47626               LARGE LEMON
# 47765       47766           ORGANIC AVOCADO
# 49234       49235       ORGANIC HALF & HALF
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Nuevamente el cálculo estuvo muy bien realizado Nicolas, lo has hecho excelente y has llegado a los resultados necesarios. Sigue así!

# %% [markdown]
# Escribe aquí tus conclusiones:
# podemos notar que la mayoria de los 20 articulos mas ordenados son iguales a los 20 mas reordenados con excepcion de un par de productos que tal vez suelen durar mas que el resto de los productos.

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
reorder_rates = order_products_df.groupby('product_id')['reordered'].agg(['sum', 'count'])
reorder_rates['reorder_rate'] = reorder_rates['sum'] / reorder_rates['count']
reorder_rates = pd.merge(reorder_rates, products_df, left_index=True, right_on='product_id')
reorder_rates = reorder_rates.sort_values(by='reorder_rate', ascending=False)
print(reorder_rates[['product_id', 'product_name', 'reorder_rate']])
# Out:
#        product_id                                       product_name  \
# 14720       14721                            BONE STRENGTH TAKE CARE
# 20948       20949                           VANILLA SANDWICH COOKIES
# 6722         6723                                   PALMIERS- PETITE
# 6731         6732                  NATURALLY SPARKLING MINERAL WATER
# 45087       45088  CALIFORNIA DILL POLLEN & GARLIC GOAT CHEESE & ...
# ...           ...                                                ...
# 10484       10485                                  CARAMEL APPLE POP
# 37689       37690  CALYPSO FRESH 2X CONCENTRATED SCENTSATIONS 166...
# 10483       10484                                 AVOCADO AND GREENS
# 10473       10474                       NUSTEVIA WHITE STEVIA POWDER
# 42983       42984  SALSA FOR ALL SEASONS HALF GUACAMOLE HALF ROAS...
#
#        reorder_rate
# 14720           1.0
# 20948           1.0
# 6722            1.0
# 6731            1.0
# 45087           1.0
# ...

# %%
order_products_df.groupby('product_id')['reordered'].mean()
# Out:
# product_id
# 1        0.564286
# 2        0.000000
# 3        0.738095
# 4        0.510204
# 7        0.500000
#            ...
# 49690    0.800000
# 49691    0.430556
# 49692    0.416667
# 49693    0.440000
# 49694    0.333333
# Name: reordered, Length: 45573, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Un cálculo preciso, muy bien hecho! Incluso si deseamos podríamos mejorarlo y resolverlo en una línea. Aquí te dejo la resolución ideal para que puedas compararlas y llegar a tus conclusiones:
#
#     order_products_df.groupby('product_id')['reordered'].mean()

# %% [markdown]
# Escribe aquí tus conclusiones:
# podemos encontrar articulos que parece ser que solo los piden una vez ya que no se vuelven a pedir mientras que hay otros que siempre se vuelven a pedir y algunos productos se piden de una manera mas aleatoria.

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
repeat_order=order_details_df.groupby('user_id')['reordered'].sum()
print(repeat_order)
# Out:
# user_id
# 2          1
# 4          0
# 5          8
# 6          0
# 7         13
#           ..
# 206203     6
# 206206    15
# 206207    41
# 206208    87
# 206209     8
# Name: reordered, Length: 149626, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Cuidado aquí Nicolas, veníamos muy bien en el calculo aunque nos mezclamos un poco en el medio. Al igual que el caso anterior podríamos resolverlo en una línea, piensa en tu cálculo de frecuencia con la agrupación inicial:
#
#     order_details_df.groupby('user_id')['reordered'].sum()
#
# aquí estas agrupando correctamente, incluso llamando a la columna correspondiente. Sin embargo el método que aplicamos no corresponde a una proporción, ¿qué podríamos implementar para obtener dichos resultados?

# %% [markdown]
#  <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 2)</b> <a class="tocSkip"></a>
#
# Excelente implementación Nicolas! Bien hecho!

# %% [markdown]
# Escribe aquí tus conclusiones:
# algunos usuarios muestran repetir los pedidos muchas veces mientras que otros no lo muestran para nada, por lo tanto algunos usuarios pueden estar acostumbrados a consumir ciertos productos constantemente mientras que otros al parecer solo los prueban y lo dejan de pedir.

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
first_added_products = order_products_df[order_products_df['add_to_cart_order'] == 1]
first_added_counts = first_added_products['product_id'].value_counts().reset_index()
first_added_counts.columns = ['product_id', 'first_added_count']
top_first_added_products = pd.merge(first_added_counts, products_df, on='product_id')
top_20_first_added = top_first_added_products.head(20)
print(top_20_first_added[['product_id', 'product_name', 'first_added_count']])
# Out:
#     product_id                 product_name  first_added_count
# 0        24852                       BANANA              15562
# 1        13176       BAG OF ORGANIC BANANAS              11026
# 2        27845           ORGANIC WHOLE MILK               4363
# 3        21137         ORGANIC STRAWBERRIES               3946
# 4        47209         ORGANIC HASS AVOCADO               3390
# 5        21903         ORGANIC BABY SPINACH               3336
# 6        47766              ORGANIC AVOCADO               3044
# 7        19660                 SPRING WATER               2336
# 8        16797                 STRAWBERRIES               2308
# 9        27966          ORGANIC RASPBERRIES               2024
# 10       44632   SPARKLING WATER GRAPEFRUIT               1914
# 11       49235          ORGANIC HALF & HALF               1797
# 12       47626                  LARGE LEMON               1737
# 13         196                         SODA               1733
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a>
#
# Aquí lo hemos hecho excelente! Bien resuelto Nicolas!

# %% [markdown]
# Escribe aquí tus conclusiones:
# aqui podemos observar los 20 productos que se agregan primero al carrito de compras los cuales suelen ser frutas y leche, estos productos deberian ser mostrados al usuario primero para que los agregue al carrito de compra.

# %% [markdown]
# ### Conclusion general del proyecto:
# Al terminar este proyecto podemos presentar la informacion que fue preparada y limpiada para poder trabajar con ella para despues tomar decisiones informadas ya que ahora podemos saber cuales son los productos preferidos de los clientes y cuando estan mas dispuestos a comprarlos, ahora sabemos cuales son los productos que generalmente ponen primero en su carrito y estos se les pueden mostrar al inicio para que los agreguen mas facil.
#
# considero que este proyecto fue mas dificil que los anteriores y esta vez tuve un contratiempo el cual intervino en mi trabajo, me siento cada vez mas preparado pero aun me falta mucho por aprender para poder trabajar yo solo ya que para este proyecto requeri de mucha ayuda de internet, un libro y compañeros. Espero en poder entregar a tiempo los siguientes trabajos y seguir aprendiendo.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Comentario del revisor. (Iteración 1) </b> <a class="tocSkip"></a>
#
# Impresionante, te agradezco tu compromiso al completar con esta conclusión que demuestra tu gran comprensión durante el proceso. Excelente!

# %%
print('creo haber respondido todos mis errores nuevamente. Gracias.')
# Out:
# creo haber respondido todos mis errores nuevamente. Gracias.

# %% [markdown]
#  <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 2)</b> <a class="tocSkip"></a>
#
# Muy bien hecho Nicolas, has podido corregir todas aquellas indicaciones marcadas en la iteración anterior, muy bien hecho!
